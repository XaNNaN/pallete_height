# %%
import pandas as pd

# %%
output = pd.read_excel("output_17_11.xlsx", index_col=0)

# %%
output[output.PALLETE_HEIGHT_FACT == 10]
# Out:
# Empty DataFrame
# Columns: [INVOICE_ID, PALLET_NO, PALLET_HEIGHT, PALLETE_HEIGHT_FACT]
# Index: []

# %%
output = output.drop(output[output.PALLETE_HEIGHT_FACT == 10].index)

# %%
output.describe()
# Out:
#           INVOICE_ID  PALLET_NO  PALLET_HEIGHT  PALLETE_HEIGHT_FACT
# count      62.000000  62.000000      62.000000            62.000000
# mean   291441.112903   1.096774    1061.306452          1048.709677
# std       303.584331   0.298064     418.997617           393.760699
# min    291037.000000   1.000000     400.000000           380.000000
# 25%    291118.250000   1.000000     733.750000           800.000000
# 50%    291614.000000   1.000000     957.000000          1000.000000
# 75%    291728.750000   1.000000    1361.000000          1247.500000
# max    291795.000000   2.000000    1998.000000          1900.000000

# %%
compare_results = output

# %%
compare_results.head(10)
# Out:
#     INVOICE_ID  PALLET_NO  PALLET_HEIGHT  PALLETE_HEIGHT_FACT
# 0       291795          1            914                  970
# 10      291790          1           1568                 1570
# 18      291785          1            607                  780
# 24      291780          1            914                  810
# 30      291775          1            697                  690
# 35      291770          1            607                  800
# 41      291765          1            400                  380
# 42      291760          1           1785                 1750
# 50      291755          1           1185                 1400
# 51      291755          2            957                  850

# %%
difference = compare_results.copy()
difference["DIF"] = abs(difference["PALLETE_HEIGHT_FACT"] - difference["PALLET_HEIGHT"])

# %%
difference.describe()
# Out:
#           INVOICE_ID  PALLET_NO  PALLET_HEIGHT  PALLETE_HEIGHT_FACT  \
# count      62.000000  62.000000      62.000000            62.000000
# mean   291441.112903   1.096774    1061.306452          1048.709677
# std       303.584331   0.298064     418.997617           393.760699
# min    291037.000000   1.000000     400.000000           380.000000
# 25%    291118.250000   1.000000     733.750000           800.000000
# 50%    291614.000000   1.000000     957.000000          1000.000000
# 75%    291728.750000   1.000000    1361.000000          1247.500000
# max    291795.000000   2.000000    1998.000000          1900.000000
#
#               DIF
# count   62.000000
# mean    89.338710
# std     69.350368
# min      0.000000
# 25%     25.500000
# 50%     86.000000
# 75%    139.500000
# max    258.000000

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    print(difference.sort_values(by=['DIF'], ascending=False))
# Out:
#      INVOICE_ID  PALLET_NO  PALLET_HEIGHT  PALLETE_HEIGHT_FACT  DIF
# 314      291072          1           1642                 1900  258
# 146      291680          1           1785                 1560  225
# 50       291755          1           1185                 1400  215
# 268      291117          1            400                  600  200
# 341      291037          1            904                 1100  196
# 326      291052          1            904                 1100  196
# 35       291770          1            607                  800  193
# 233      291147          1            814                 1000  186
# 248      291132          1            814                 1000  186
# 18       291785          1            607                  780  173
# 272      291112          1           1164                 1000  164
# 294      291087          1           1404                 1250  154
# 208      291190          1           1244                 1100  144
# ...

# %%
difference.sort_values(by=['DIF'], ascending=False)
# Out:
#      INVOICE_ID  PALLET_NO  PALLET_HEIGHT  PALLETE_HEIGHT_FACT  DIF
# 314      291072          1           1642                 1900  258
# 146      291680          1           1785                 1560  225
# 50       291755          1           1185                 1400  215
# 268      291117          1            400                  600  200
# 341      291037          1            904                 1100  196
# ..          ...        ...            ...                  ...  ...
# 10       291790          1           1568                 1570    2
# 317      291072          2            650                  650    0
# 97       291725          2            840                  840    0
# 333      291047          1            400                  400    0
# 287      291097          1            500                  500    0
#
# [62 rows x 5 columns]
